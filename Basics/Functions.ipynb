# %% [markdown]
# #### Write a Function to calculate and return the square of a number

# %%
def square (x):
    return x*x

a=square(2)
print(a)    

# if we had use print instead of return we cant store the value in (a).

#Parameter = the variable in the function definition.
# Argument = the value supplied to that variable when the function is called.
# Out:
# 4

# %% [markdown]
# #### Create a function that takes two number as parameters and return their sum

# %%
def add_1(x,y):
    return x+y


a=add_1(2,3)
print(a)
# Out:
# 5

# %% [markdown]
# #### Polymorphism func - Write a func that multiples two numbers, but can also accept and multiply strings.

# %%
def multiply(a,b):
    return a*b


x=multiply(2,3)
z=multiply(5,"c")

print(x)
print(z)
# Out:
# 6
# ccccc

# %% [markdown]
# #### Create a func that returns both the area and circumferenc of a circle given its radius

# %%
def info(r):
    area=3.14*r*r
    circumference=2*3.14*r
    # return ("area of circle is : ",area,"circumference of circle is : ",circumference)
    return area,circumference

a,c=info(3)
# print("Area : ",a, "Circumference : ",c)
print(f"Area: {a:.2f}, Circumference: {c:.2f}")
# Out:
# Area: 28.26, Circumference: 18.84

# %% [markdown]
# #### Wrie a function that greets a user, if no name , it should greet with default

# %%
def greet(user="Anonymous"):
    return f"Hello! {user}"

print(greet("John"))
print(greet("Doe"))
print(greet())
# Out:
# Hello! John
# Hello! Doe
# Hello! Anonymous

# %% [markdown]
# #### Create  lambda function to compute the cube of number

# %%
cube=lambda x : x**3

print(cube(3))
# Out:
# 27

# %% [markdown]
# #### Func with *args

# %%
def sum_all(*args):
    return sum(args)

print(sum_all(1,2))
print(sum_all(1,2,3,4,5,6))
# Out:
# 3
# 21

# %% [markdown]
# #### func with **kwargs

# %%
def a_kwargs(**kwargs):
    for key,value in kwargs.items():
        print(f"{key}:{value}")
        
        
a_kwargs(name="a",age=22,role="lifter")
# Out:
# name:a
# age:22
# role:lifter

# %% [markdown]
# #### Recursive function

# %%
def fact(n):
    if n==0:
        return 1
    else :
        return n* fact(n-1)
    
fact(5)
# Out:
# 120

# %% [markdown]
# ### Calculator using Functions

# %%
def add(*nums):
    return sum(nums)

def subtract(*nums):
    result = nums[0]
    for i in nums[1:]:
        result -= i
    return result

def multiply(*nums):
    result = 1
    for i in nums:
        result *= i
    return result

def divide(*nums):
    result = nums[0]
    for i in nums[1:]:
        if i == 0:
            return "Cannot divide by zero!"
        result /= i
    return result

print("1. Add")
print("2. Subtract")
print("3. Multiply")
print("4. Divide")

choice = int(input("Enter choice: "))

nums = list(map(float, input("Enter numbers separated by space: ").split()))

if choice == 1:
    print("Answer:", add(*nums))
elif choice == 2:
    print("Answer:", subtract(*nums))
elif choice == 3:
    print("Answer:", multiply(*nums))
elif choice == 4:
    print("Answer:", divide(*nums))
else:
    print("Invalid choice")
# Out:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# Answer: 15.0

# %% [markdown]
# ### LArgest in List

# %%
def largest (lst):
    
    lar=lst[0]
    
    for i in lst:
        if i >lar:
            lar=i
    print(lar)

largest([12,3,4,6])
# Out:
# 12

# %% [markdown]
# ### Check Frequency

# %%
a="Bananaaaa"
c={}

for ch in a:
    if ch in c:
        c[ch]+=1
    else:
        c[ch]=1
        
print(c)
# Out:
# {'B': 1, 'a': 6, 'n': 2}

# %% [markdown]
# #### Create a Complete Student Management System using Functions

# %%
students = []


def calculate_grade(percentage):
    if percentage >= 90:
        return "A+"
    elif percentage >= 80:
        return "A"
    elif percentage >= 70:
        return "B"
    elif percentage >= 60:
        return "C"
    elif percentage >= 50:
        return "D"
    else:
        return "F"


def add_student():
    roll = input("Enter Roll Number: ")
    name = input("Enter Name: ")

    m1 = int(input("Enter Marks of Subject 1: "))
    m2 = int(input("Enter Marks of Subject 2: "))
    m3 = int(input("Enter Marks of Subject 3: "))

    total = m1 + m2 + m3
    percentage = total / 3
    grade = calculate_grade(percentage)

    if percentage >= 35:
        result = "Pass"
    else:
        result = "Fail"

    student = {
        "Roll": roll,
        "Name": name,
        "Marks": [m1, m2, m3],
        "Total": total,
        "Percentage": percentage,
        "Grade": grade,
        "Result": result
    }

    students.append(student)
    print("Student Added Successfully")


def view_students():

    if len(students) == 0:
        print("No Student Found")
        return

    for student in students:
        print(student)


def search_student():

    roll = input("Enter Roll Number: ")

    for student in students:
        if student["Roll"] == roll:
            print(student)
            return

    print("Student Not Found")


def update_student():

    roll = input("Enter Roll Number: ")

    for student in students:

        if student["Roll"] == roll:

            student["Name"] = input("Enter New Name: ")

            m1 = int(input("Subject 1 Marks: "))
            m2 = int(input("Subject 2 Marks: "))
            m3 = int(input("Subject 3 Marks: "))

            total = m1 + m2 + m3
            percentage = total / 3

            student["Marks"] = [m1, m2, m3]
            student["Total"] = total
            student["Percentage"] = percentage
            student["Grade"] = calculate_grade(percentage)

            if percentage >= 35:
                student["Result"] = "Pass"
            else:
                student["Result"] = "Fail"

            print("Student Updated Successfully")
            return

    print("Student Not Found")


def delete_student():

    roll = input("Enter Roll Number: ")

    for student in students:
        if student["Roll"] == roll:
            students.remove(student)
            print("Student Deleted Successfully")
            return

    print("Student Not Found")


def menu():

    while True:

        print("\n===== Student Management System =====")
        print("1. Add Student")
        print("2. View Students")
        print("3. Search Student")
        print("4. Update Student")
        print("5. Delete Student")
        print("6. Exit")

        choice = int(input("Enter Choice: "))

        if choice == 1:
            add_student()

        elif choice == 2:
            view_students()

        elif choice == 3:
            search_student()

        elif choice == 4:
            update_student()

        elif choice == 5:
            delete_student()

        elif choice == 6:
            print("Thank You")
            break

        else:
            print("Invalid Choice")


menu()
# Out:
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Student Added Successfully
#
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# {'Roll': '12', 'Name': 'yash', 'Marks': [25, 24, 23], 'Total': 72, 'Percentage': 24.0, 'Grade': 'F', 'Result': 'Fail'}
#
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# {'Roll': '12', 'Name': 'yash', 'Marks': [25, 24, 23], 'Total': 72, 'Percentage': 24.0, 'Grade': 'F', 'Result': 'Fail'}
#
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Thank You

# %%
def c(x):
    y=lambda a : a*a
    print(y(x))
c(2)
